# %%
import pandas as pd

# 1) 改成你的文件路径（例如 "./DMEFExtractSummaryV01.CSV"）
path = "DMEFExtractSummaryV01.CSV"

# 2) 读取（这个文件列很多，我先关掉低内存提示）
df = pd.read_csv(path, low_memory=False)

# 3) 快速确认读成功
print("Rows, Cols =", df.shape)
print(df.head(3))
# Out:
# Rows, Cols = (100051, 170)
#    Cust_ID SCF_Code  RetF07Dollars  RetF07Trips  RetF07Lines  RetS07Dollars  \
# 0    22120      346              0            0            0              0
# 1    24436                       0            0            0              0
# 2    29278       85              0            0            0              0
#
#    RetS07Trips  RetS07Lines  RetF06Dollars  RetF06Trips  ...  IncCode  \
# 0            0            0             14            1  ...        8
# 1            0            0              0            0  ...
# 2            0            0             63            2  ...        9
#
#    HomeCode  Child0_2  Child3_5  Child6_11  Child12_16  Child17_18  Dwelling  \
# 0         2         N         N          N           N           N         1
# 1                   N         N          N           N           N
# 2         2         N         N          N           N           N         2
#
#    LengthRes  HomeValue
# 0          8          0
# 1          3          0
# 2          2          0
#
# [3 rows x 170 columns]

# %%
# 检查关键渠道变量是否存在
cols_to_check = ['RetF07Dollars', 'IntF07Orders', 'CatF07Orders']
print([col for col in cols_to_check if col in df.columns])
# Out:
# ['RetF07Dollars', 'IntF07Orders', 'CatF07Orders']

# %%
# 判断是否使用渠道（大于0就算使用）
df['Used_Retail'] = df['RetF07Dollars'] > 0
df['Used_Internet'] = df['IntF07Orders'] > 0
df['Used_Catalog'] = df['CatF07Orders'] > 0

# 看看有多少人使用每个渠道
print("Retail users:", df['Used_Retail'].sum())
print("Internet users:", df['Used_Internet'].sum())
print("Catalog users:", df['Used_Catalog'].sum())
# Out:
# Retail users: 8841
# Internet users: 6700
# Catalog users: 6150

# %%
df[['RetF07Dollars','IntF07Orders','CatF07Orders']].isnull().sum()
# Out:
# RetF07Dollars    0
# IntF07Orders     0
# CatF07Orders     0
# dtype: int64

# %%
df['Channel_Count'] = (
    df['Used_Retail'].astype(int) +
    df['Used_Internet'].astype(int) +
    df['Used_Catalog'].astype(int)
)

df['Channel_Count'].value_counts()
# Out:
# Channel_Count
# 0    78791
# 1    20833
# 2      423
# 3        4
# Name: count, dtype: int64

# %%
# 是否“多渠道”（>=2）
df['Multi_Channel'] = df['Channel_Count'] >= 2
df['Multi_Channel'].value_counts()
# Out:
# Multi_Channel
# False    99624
# True       427
# Name: count, dtype: int64

# %%
# 多渠道客户是否花更多钱？
df.groupby('Channel_Count')['RetF07Dollars'].mean()
# Out:
# Channel_Count
# 0     0.000000
# 1    30.965727
# 2    78.271868
# 3    94.000000
# Name: RetF07Dollars, dtype: float64

# %%
cols = ['Channel_Count','IncCode','AgeCode','HomeValue']
print(df[cols].dtypes)
# Out:
# Channel_Count     int64
# IncCode          object
# AgeCode          object
# HomeValue        object
# dtype: object

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

cols = ['Channel_Count','IncCode','AgeCode','HomeValue']

# 转成数值，不能转的变成 NaN
for c in cols:
    df[c] = pd.to_numeric(df[c], errors='coerce')

print(df[cols].dtypes)
print(df[cols].isnull().sum())
# Out:
# Channel_Count      int64
# IncCode          float64
# AgeCode          float64
# HomeValue        float64
# dtype: object
# Channel_Count        0
# IncCode          34710
# AgeCode          21977
# HomeValue        16961
# dtype: int64

# %%
reg_df = df[['RetF07Dollars'] + cols].dropna()

X = reg_df[cols]
y = reg_df['RetF07Dollars']

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          RetF07Dollars   R-squared:                       0.122
# Model:                            OLS   Adj. R-squared:                  0.122
# Method:                 Least Squares   F-statistic:                     2265.
# Date:                Fri, 20 Feb 2026   Prob (F-statistic):               0.00
# Time:                        16:02:30   Log-Likelihood:            -3.1114e+05
# No. Observations:               65341   AIC:                         6.223e+05
# Df Residuals:                   65336   BIC:                         6.223e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.2661      0.582     -0.457      0.647      -1.407       0.874
# Channel_Count    29.4158      0.310     94.950      0.000      28.809      30.023
# IncCode           0.0514      0.053      0.973      0.330      -0.052       0.155
# AgeCode          -0.0355      0.087     -0.409      0.682      -0.205       0.134
# HomeValue     -9.482e-07   1.12e-06     -0.848      0.397   -3.14e-06    1.24e-06
# ==============================================================================
# Omnibus:                   147527.045   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       2534490199.660
# Skew:                          21.105   Prob(JB):                         0.00
# Kurtosis:                     966.922   Cond. No.                     6.04e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.04e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# 重新创建 3个渠道是否使用（True/False）
df['Used_Retail']   = df['RetF07Dollars'] > 0
df['Used_Internet'] = df['IntF07Orders'] > 0
df['Used_Catalog']  = df['CatF07Orders'] > 0

# 看看是不是创建成功
df[['Used_Retail','Used_Internet','Used_Catalog']].head()
# Out:
#    Used_Retail  Used_Internet  Used_Catalog
# 0        False          False         False
# 1        False          False         False
# 2        False          False          True
# 3        False          False         False
# 4        False          False         False

# %%
df['Used_Retail']   = df['Used_Retail'].astype(int)
df['Used_Internet'] = df['Used_Internet'].astype(int)
df['Used_Catalog']  = df['Used_Catalog'].astype(int)

df[['Used_Retail','Used_Internet','Used_Catalog']].describe()
# Out:
#          Used_Retail  Used_Internet   Used_Catalog
# count  100051.000000  100051.000000  100051.000000
# mean        0.088365       0.066966       0.061469
# std         0.283826       0.249964       0.240189
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000

# %%
import statsmodels.api as sm
import pandas as pd

# 取需要的列
reg_cols = ['Used_Retail','Used_Internet','Used_Catalog','IncCode','AgeCode','HomeValue','RetF07Dollars']
reg_df = df[reg_cols].copy()

# 转成数值（避免 object 报错）
for c in ['IncCode','AgeCode','HomeValue']:
    reg_df[c] = pd.to_numeric(reg_df[c], errors='coerce')

reg_df = reg_df.dropna()

X = reg_df[['Used_Retail','Used_Internet','Used_Catalog','IncCode','AgeCode','HomeValue']]
y = reg_df['RetF07Dollars']

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          RetF07Dollars   R-squared:                       0.364
# Model:                            OLS   Adj. R-squared:                  0.364
# Method:                 Least Squares   F-statistic:                     6220.
# Date:                Fri, 20 Feb 2026   Prob (F-statistic):               0.00
# Time:                        16:03:20   Log-Likelihood:            -3.0062e+05
# No. Observations:               65341   AIC:                         6.013e+05
# Df Residuals:                   65334   BIC:                         6.013e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -1.8099      0.496     -3.651      0.000      -2.782      -0.838
# Used_Retail      87.2322      0.452    192.988      0.000      86.346      88.118
# Used_Internet     1.4516      0.473      3.066      0.002       0.524       2.380
# Used_Catalog      0.6449      0.426      1.514      0.130      -0.190       1.480
# IncCode           0.1444      0.045      3.211      0.001       0.056       0.233
# AgeCode           0.1897      0.074      2.559      0.010       0.044       0.335
# HomeValue      -9.67e-07   9.52e-07     -1.015      0.310   -2.83e-06       9e-07
# ==============================================================================
# Omnibus:                   163224.898   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       6573772879.157
# Skew:                          26.940   Prob(JB):                         0.00
# Kurtosis:                    1555.955   Cond. No.                     6.07e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.07e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
